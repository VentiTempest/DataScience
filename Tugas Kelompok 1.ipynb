# %% [markdown]
# TUGAS KELOMPOK 1

# %% [markdown]
# Anggota Kelompok:
# 1. I Gede Eka Agung Agastya Punia (2502121143)
# 2. Mufida Salma (2502127153)
# 3. Dirgam Fahlevi (2502123325)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel('./DataTK1.xlsx', sheet_name='Sheet1')

# %%
df.head()
# Out:
#    NO JENIS KELAMIN STATUS MAHASISWA STATUS PERNIKAHAN IPK SEMESTER 1-6  \
# 0   1   LAKI - LAKI        MAHASISWA             BELUM             3,17
# 1   2   LAKI - LAKI          BEKERJA             BELUM             3,30
# 2   3     PEREMPUAN        MAHASISWA             BELUM             3,01
# 3   4     PEREMPUAN        MAHASISWA           MENIKAH             3,25
# 4   5   LAKI - LAKI          BEKERJA           MENIKAH             3,20
#
#   STATUS KELULUSAN
# 0            TEPAT
# 1            TEPAT
# 2            TEPAT
# 3            TEPAT
# 4            TEPAT

# %% [markdown]
# A. Untuk menggambarkan hubungan antara jenis kelamin dan status kelulusan.

# %%
plt.figure(figsize=(8, 6))
count_plot = sns.countplot(data=df, x='JENIS KELAMIN', hue='STATUS KELULUSAN')

# %% [markdown]
# B. Untuk menggambarkan hubungan antara status mahasiswa dan IPK semester 1-6.

# %%
data = {
    'Mahasiswa': np.array(df[df['STATUS MAHASISWA'] == 'MAHASISWA']['IPK SEMESTER 1-6'].str.replace(',', '.')).astype(float),
    'Bekerja': np.array(df[df['STATUS MAHASISWA'] == 'BEKERJA']['IPK SEMESTER 1-6'].str.replace(',', '.')).astype(float)
}

print(data)

plt.boxplot(data.values(), labels=data.keys())
plt.xlabel('Status Mahasiswa')
plt.ylabel('IPK')
plt.title('Distribusi IPK Berdasarkan Status Mahasiswa')
plt.show()
# Out:
# {'Mahasiswa': array([3.17, 3.01, 3.25, 2.5 , 2.5 , 3.5 , 3.25, 2.3 ]), 'Bekerja': array([3.3, 3.2, 2.5, 3. , 2.7, 2.4, 3.3])}

# %% [markdown]
# C.Untuk menggambarkan tren ketepatan waktu lulus di setiap status mahasiswa.

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='STATUS MAHASISWA', hue='STATUS KELULUSAN')
plt.xlabel('Status Mahasiswa')
plt.ylabel('Jumlah Mahasiswa')
plt.title('Tren Ketepatan Waktu Lulus Berdasarkan Status Mahasiswa')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='STATUS PERNIKAHAN', hue='STATUS KELULUSAN')
plt.xlabel('Status Pernikahan')
plt.ylabel('Jumlah Mahasiswa')
plt.title('Tren Ketepatan Waktu Lulus Berdasarkan Status Pernikahan')
plt.show()
